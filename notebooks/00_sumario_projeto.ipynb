# %%
# Criar notebook de revisão: notebooks/00_project_summary.ipynb

# Célula 1: Sumário executivo
print("=" * 80)
print("📊 SUMÁRIO EXECUTIVO DO PROJETO - SEMANAS 1-2")
print("=" * 80)

import pandas as pd
import os

# Verificar arquivos criados
print("\n📁 ARQUIVOS CRIADOS:")
notebooks = os.listdir(r'C:\Users\wesle\anaconda3\envs\Credit_Score_Project\notebooks')
print(f"   Notebooks: {len(notebooks)}")
for nb in sorted(notebooks):
    print(f"      - {nb}")

# Estatísticas dos dados
df_original = pd.read_csv('../data/raw_data/cs-training.csv')
df_clean = pd.read_csv('../data/processed_data/df_cleaned.csv')

print(f"\n📊 ESTATÍSTICAS:")
print(f"   Dataset original: {df_original.shape}")
print(f"   Dataset limpo: {df_clean.shape}")
print(f"   Redução: {df_original.shape[0] - df_clean.shape[0]:,} linhas")
print(f"   Colunas removidas: {df_original.shape[1] - df_clean.shape[1]}")

# Status do projeto
print(f"\n✅ STATUS DO PROJETO:")
checklist = {
    "Setup ambiente": "✅ Completo",
    "EDA inicial": "✅ Completo",
    "Análise bivariada": "✅ Completo",
    "Limpeza de dados": "✅ Completo",
    "Feature engineering": "📅 Essa semana",
    "Modelagem": "📅 Semana 4",
    "Dashboard": "📅 Semana 5"
}

for task, status in checklist.items():
    print(f"   {task:25s}: {status}")
# Out:
# ...
# 📊 SUMÁRIO EXECUTIVO DO PROJETO - SEMANAS 1-2
# ...
#
# 📁 ARQUIVOS CRIADOS:
#    Notebooks: 6
#       - .ipynb_checkpoints
#       - 00_sumario_projeto.ipynb
#       - 01_data_exploration.ipynb
#       - 02_bivariate_analysis.ipynb
#       - 03_data_cleaning.ipynb
#       - 04_bivariate_iv_analysis_clean.ipynb
#
# 📊 ESTATÍSTICAS:
#    Dataset original: (150000, 12)
#    Dataset limpo: (149234, 20)
#    Redução: 766 linhas
#    Colunas removidas: -8
#
# ✅ STATUS DO PROJETO:
#    Setup ambiente           : ✅ Completo
#    EDA inicial              : ✅ Completo
#    Análise bivariada        : ✅ Completo
#    Limpeza de dados         : ✅ Completo
#    Feature engineering      : 📅 Próxima semana
#    Modelagem                : 📅 Semana 4
#    Dashboard                : 📅 Semana 5

# %%
# Out:
# C:\Users\wesle\anaconda3\envs\Credit_Score_Project\notebooks
